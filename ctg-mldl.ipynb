# %%
from ctg_parser import clean_json
import pandas as pd

# %%
path = 'data/ctg-studies-mldl.json'
df = clean_json(path, 'data/ctg-studies-mldl-clean.csv')
df.head()
# Out:
# Saved CSV to data/ctg-studies-mldl-clean.csv
#         nct_id                                  org_name org_class  \
# 0  NCT06459128                            Limbic Limited  INDUSTRY
# 1  NCT04640090  Washington University School of Medicine     OTHER
# 2  NCT04440553        University of California, Berkeley     OTHER
# 3  NCT04046497                          Northwell Health     OTHER
# 4  NCT06965296   State University of New York at Buffalo     OTHER
#
#                                          brief_title overall_status  \
# 0  Delivery Format of Cognitive Behavioral Therap...      COMPLETED
# 1                     Wellness Through Mobile Health      COMPLETED
# 2  A Mobile App to Increase Physical Activity in ...      COMPLETED
# 3  Artificial Intelligence to Measure Adherence t...     RECRUITING
# 4  AI-Enhanced App-based Intervention for Adolesc...     RECRUITING
#
#   why_stopped                                      collaborators has_dmc  \
# ...

# %%
df[df['fda_regulated_device'] == True].to_csv('data/ctg-studies-mldl-fda-regulated-devices.csv', index=False)
