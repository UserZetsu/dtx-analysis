# %%
from ctg_parser import clean_json
import pandas as pd

# %%
path = 'data/ctg-studies-mldl.json'
clean_json(path, 'data/ctg-studies-mldl-clean.csv')
# Out:
# Saved CSV to data/ctg-studies-mldl-clean.csv
#            nct_id  ...                                           keywords
# 0     NCT06459128  ...  [ai, llm, cbt, cognitive behavioural therapy, ...
# 1     NCT04640090  ...  [Musculoskeletal disease, Chronic pain, Behavi...
# 2     NCT04440553  ...                                               None
# 3     NCT04046497  ...                                               None
# 4     NCT06965296  ...  [Adolescent e-cigarette use, E-cigarette cessa...
# ...           ...  ...                                                ...
# 1021  NCT05545943  ...  [cognition, motor function, metabolism, young ...
# 1022  NCT06389175  ...  [major depressive disorder, stomach-brain coup...
# 1023  NCT04781491  ...  [Forest Therapy, Forest Bathing, Shinrin Yoku,...
# 1024  NCT06457412  ...          [Obesity, Childhood, Grupal intervention]
# 1025  NCT02395172  ...  [Avelumab, MSB0010718C, Non-Small Cell Lung Ca...
#
# [1026 rows x 13 columns]
