# %%
import pandas as pd
import ast
df = pd.read_csv('data/pulled_ctg_studies.csv')
df.head()
# Out:
#         nct_id                  org_name org_class  \
# 0  NCT05838625  Click Therapeutics, Inc.  INDUSTRY
# 1  NCT06791122      Boehringer Ingelheim  INDUSTRY
# 2  NCT06230445    Sun Yat-sen University     OTHER
# 3  NCT06004388  Click Therapeutics, Inc.  INDUSTRY
# 4  NCT05375500          Karuna Labs Inc.  INDUSTRY
#
#                                          brief_title         overall_status  \
# 0  Study of Two Digital Therapeutics for the Trea...  ACTIVE_NOT_RECRUITING
# 1  A Prospective Cohort Study to Assess Clinical ...             RECRUITING
# 2  Effects of Digital Therapeutic in Whole Proces...             RECRUITING
# 3  Study of Two Digital Therapeutics for the Prev...              COMPLETED
# 4  Embodiment in Virtual Reality as a Telemedicin...              COMPLETED
#
#   why_stopped                                      collaborators has_dmc  \
# 0         NaN  [{'name': 'Boehringer Ingelheim', 'class': 'IN...    True
# 1         NaN                                                NaN   False
# 2         NaN                                                NaN   False
# 3         NaN                                                NaN    True
# 4         NaN                                                NaN   False
#
#   fda_regulated_drug fda_regulated_device   phase  \
# 0              False                 True  PHASE3
# 1              False                 True     NaN
# 2              False                False  PHASE3
# 3              False                 True  PHASE3
# 4              False                 True     NaN
#
#                                           conditions  \
# 0                                  ['Schizophrenia']
# 1                                  ['Schizophrenia']
# 2  ['Application of Digital Therapeutic in Lung C...
# 3  ['Migraine', 'Episodic Migraine', 'Headache', ...
# 4  ['Chronic Pain', 'Low Back Pain', 'Shoulder Pa...
#
#                                             keywords
# 0  ['Prescription digital therapeutic (PDT)', 'So...
# 1                                                NaN
# 2  ['Digital therapeutic', 'Whole process managem...
# 3  ['Prescription digital therapeutic (PDT)', 'So...
# 4                                                NaN

# %% [markdown]
# ### General Descriptive Statistics

# %%
# Organizations that have their digital therapeutics listed in ClinicalTrials.gov
df['org_name'].value_counts()
# Out:
# org_name
# Click Therapeutics, Inc.                          10
# Woebot Health                                      6
# Better Therapeutics                                4
# NightWare                                          4
# Limbix Health, Inc.                                3
#                                                   ..
# University of Utah                                 1
# Norwegian University of Science and Technology     1
# Northwestern University                            1
# Tesu Saglik Teknolojileri A.S.                     1
# Fundació Sant Joan de Déu                          1
# Name: count, Length: 87, dtype: int64

# %%
# Organizational classification 
df['org_class'].value_counts()
# Out:
# org_class
# INDUSTRY    75
# OTHER       53
# Name: count, dtype: int64

# %%
# Proportion of status of digital therapeutics
df['overall_status'].value_counts()
# Out:
# overall_status
# COMPLETED                  64
# ACTIVE_NOT_RECRUITING      16
# RECRUITING                 15
# NOT_YET_RECRUITING         10
# TERMINATED                 10
# UNKNOWN                     9
# WITHDRAWN                   3
# ENROLLING_BY_INVITATION     1
# Name: count, dtype: int64

# %%
# Reasons for termination of clinical trials
termination_reason = df['why_stopped'].value_counts()
termination_reason = termination_reason.reset_index()
termination_reason.columns = ['Reason', 'Count']

termination_reason
# Out:
#                                                Reason  Count
# 0                              recruitment challenges      1
# 1   COVID and the Study was withdrawn (limited rec...      1
# 2   Terminated due to difficulty enrolling patient...      1
# 3                                  Enrollment too low      1
# 4                           Internal company decision      1
# 5   Change of company's priority; learning from a ...      1
# 6                                     loss of funding      1
# 7                                      Low Enrollment      1
# 8   Data Safety Monitoring Board (DSMB) recommenda...      1
# 9                       Sponsor/Investigator Decision      1
# 10  Decided not to proceed with the study at this ...      1
# 11                  The PI decided to stop the study.      1
# 12  ReSET-O product no longer available, Pear Ther...      1

# %%
# Interesting to see the collaborators. Potentially useful.
collabs = dict()
for i in df['collaborators']:
    if pd.isna(i):
        continue   
    else:
        i = ast.literal_eval(i)
        for j in i:
            name = j['name']
            if name in collabs:
                collabs[name] += 1
            else:
                collabs[name] = 1
             
collabs = pd.DataFrame(list(collabs.items()), columns=['Collaborators', 'Count']).sort_values(by='Count', ascending=False)
collabs
# Out:
#                                   Collaborators  Count
# 13      National Institute on Drug Abuse (NIDA)     11
# 2    National Institute of Mental Health (NIMH)      5
# 0                          Boehringer Ingelheim      4
# 70  Minneapolis Veterans Affairs Medical Center      2
# 58                                RationalPsych      2
# ..                                          ...    ...
# 31                 Akili Interactive Labs, Inc.      1
# 30                             Brown University      1
# 29                                Iqvia Pty Ltd      1
# 28                                     LifeScan      1
# 97                     Swing Therapeutics, Inc.      1
#
# [98 rows x 2 columns]

# %%
# Number of studies with DMC 
# DMC = Data Monitoring Committee and is a group important in clinical research in psychiatry because they provide an added layer of protection for vulnerable populations 
# https://pmc.ncbi.nlm.nih.gov/articles/PMC4118004/
dmc = df['has_dmc'].value_counts()
dmc = dmc.reset_index()
dmc.columns = ['DMC', 'Count']
dmc['DMC'] = dmc['DMC'].replace({True: 'Yes', False: 'No'})
dmc
# Out:
#    DMC  Count
# 0   No     79
# 1  Yes     36

# %%
# Number of FDA Regulated Device 
fda_device = df['fda_regulated_device'].value_counts() 
fda_device = fda_device.reset_index()
fda_device.columns = ['FDA Regulated Device', 'Count']
fda_device['FDA Regulated Device'] = fda_device['FDA Regulated Device'].replace({True: 'Yes', False: 'No'})
fda_device
# Out:
#   FDA Regulated Device  Count
# 0                   No     69
# 1                  Yes     58

# %%
phases = df['phase'].value_counts(dropna=False)
phases = phases.reset_index()
phases.columns = ['Phase', 'Count']
phases['Phase'] = phases['Phase'].replace({None: 'N/A'})

phases
# Out:
#     Phase  Count
# 0     N/A    114
# 1  PHASE3      9
# 2  PHASE2      4
# 3  PHASE1      1

# %%
# Conditions that Dtx are being tested for
conditions = dict()
for i in df['conditions']:
    if pd.isna(i):
        continue   
    else:
        i = ast.literal_eval(i)
        for j in i:
            if j in conditions:
                conditions[j] += 1
            else:
                conditions[j] = 1

conditions = pd.DataFrame(list(conditions.items()), columns=['Conditions', 'Count']).sort_values(by='Count', ascending=False)
conditions
# Out:
#                               Conditions  Count
# 0                          Schizophrenia      8
# 43                            Depression      8
# 132                            Nightmare      5
# 19             Diabetes Mellitus, Type 2      4
# 20               Substance Use Disorders      4
# ..                                   ...    ...
# 73   Dysarthria as Late Effect of Stroke      1
# 72                       Pain Perception      1
# 71                     Anxiety Disorders      1
# 70                 Postpartum Depression      1
# 176              Decompensated Cirrhosis      1
#
# [177 rows x 2 columns]

# %%
# Conditions that Dtx are being tested for
keywords_dict = dict()
for i in df['keywords']:
    if pd.isna(i):
        continue   
    else:
        i = ast.literal_eval(i)
        for j in i:
            if j in conditions:
                keywords_dict[j] += 1
            else:
                keywords_dict[j] = 1

keywords_dict = pd.DataFrame(list(keywords_dict.items()), columns=['Conditions', 'Count']).sort_values(by='Count', ascending=False)

# for condition in keywords_dict['Conditions']:
#     print(condition)
# Out:
# Prescription digital therapeutic (PDT)
# Therapeutic Education Application
# Self Help
# immunotherapy
# checkpoint inhibitors
# immune-related adverse events
# Clinical Trials, Randomized
# Prevention
# eHealth
# Anxiety Sensitivity
# Adolescence
# Behavioral Activation
# antithrombotic treatment
# digital therapeutic application assistance
# Nightmare Disorder
# Post-traumatic stress disorder
# Veteran
# Digital medicine
# Nightmares
# Overactive bladder
# Urge incontinence
# Pelvic floor disorders
# Nervous System Diseases
# Movement Disorders
# Neurodegenerative Diseases
# Brain Diseases
# Central Nervous System Diseases
# Nightmare
# Problematic Screen Use
# Cognitive Behavioral Therapy
# Irritable Bowel Syndrome
# reduced emotional expression
# sildenafil
# Schizoaffective disorder
# Major Depressive Disorder
# MDD
# Augmented Reality
# behavioral
# critical care
# behavior modification
# Mindfulness
# Virtual Reality
# Opioid Use Disorder
# iontophoresis
# cutaneous microcirculation
# Healthy volunteers
# reduced social engagement
# CBT
# smartphone app
# mental disorder
# psychosis
# acute psychotic reaction
# chronic psychosis
# failure to recognize what is real
# false beliefs
# unclear thinking,
# confused thinking
# auditory hallucinations
# paranoia
# Digital Therapeutics
# Young People
# Software as a Medical Device (SaMD)
# Physical Health
# Virtual Reality (VR)
# Health Recommender System
# I-Change Behavioral Change Model
# Artificial Intelligence (AI)
# PostPartum depression (PPD), symptoms of PPD, Anxiety, Peri-natal depression, mild-to-moderate depression
# Attention Biases
# Cognition
# Multiple Sclerosis
# substance use disorders
# implementation science
# randomized controlled trial
# factorial trial
# opioid use disorders
# Implementation Science
# Mobile Applications
# Drug Use Disorders
# Quality Improvement
# Primary Health Care
# Alcohol Use Disorder
# Substance Use Disorder
# AUD
# SUD
# AUD Treatment
# SUD Treatment
# Smartphone Application
# Alcohol Use Disorder Treatment
# Substance Use Disorder Treatment
# mHealth Device
# Pre-operative Stress
# User-centred design
# recovery coach
# digital therapy
# cognitive behavioral therapy
# Cognitive Training Video Game
# Software-as-a Medical Device (SaMD)
# sleep
# oxidative stress
# aging
# inflammation
# sex/gender
# contingency management
# motivational incentives
# recovery
# recovery coaching
# Registry
# telehealth
# remote monitoring
# drug testing
# breathalyzer
# Medicaid
# alcoholism
# alcohol abuse
# addiction
# ADHD
# AKL-T01
# EndeavorRx
# Akili
# habits
# behavior change
# rhythmic auditory stimulation
# Parkinson disease
# cancer
# digital solution
# lifestyle change
# prostate cancer
# quality of life
# digital intervention
# side effects
# medication adherence
# physical activity
# colorectal cancer
# lung cancer
# insomnia
# CBT-I
# Mental Health
# Adolescent
# Digital Therapeutic
# Chatbot
# Mental Health App
# Smartphone
# Social support
# Randomized controlled trial
# Breast Cancer
# Colon/Rectal Cancer
# Endometrial Cancer
# Lymphoma
# Leukemia
# Lung Cancer
# psychotherapy
# pain interference
# pain function
# postpartum pelvic floor
# Smartphone app
# Schizophrenia
# Negative Symptoms
# Digital therapeutic
# Whole process management
# Lung cancer
# Patient follow-up
# CGRP
# Calcitonin Gene-Related Peptide Inhibitor Therapy
# PTSD
# Exercise
# postpartum pelvic muscle training
# postpartum pelvic floor physical therapy
# mobile app
# postpartum urinary incontinence
# postpartum bowel incontinence
# postpartum pelvic floor recovery
# digital
# mobile health
# autism
# pediatrics
# depression
# anxiety
# chronic pain
# primary care
# digital therapeutic
# Ovarian Cancer
# Pancreatic Cancer
# Prostate Cancer
# Tobacco Abstinence
# Language Disorders
# speech rehabilitation
# application
# Post-stroke dysarthria
# Smoking
# Cigarette Smoking
# Tobacco Smoking
# Nicotine
# Drug
# Addiction
# Tobacco
# Human immunodeficiency virus (HIV)
# Quit Smoking
# digital therapeutics
# Colorectal Cancer
# Fatigue
# Adolescent mental health
# Patient adherence
# Mobile application
# Mobile health
# Digital therapeutics
# Digital health
# Overactive Bladder (OAB)
# Physicians
# Cognitive Behavioral Therapy for Insomnia
# Cognitive performance
# Speech Disorders
# Stroke
# Thyroid Cancer
# Chronic Insomnia
# BCBT
# Suicide Ideation
# Suicide Attempts
# Depression and Anxiety
# Prediabetic State
# Mobile Health
# Digital Health
# Mobile Apps
# Lifestyle Modification
# mHealth
# Depression
# Adolescent Depression
# Smoking Cessation
# Dysarthria
# Smoking Cessation Program
# Smoking Cessation Digital Therapeutic
# Postpartum Depression
# PPD
# Postpartum Depression Treatment
# PPD Treatment
# Smartphone application
# Anxiety, worry, mindfulness, meditation
# Pain
# Emotions
# virtual reality
# within-subject design
# Hyoid bone, twin block, motion,

# %%
for i in df['keywords']:
    print(i)
# Out:
# ['Prescription digital therapeutic (PDT)', 'Software as a Medical Device (SaMD)', 'Smartphone app', 'Schizophrenia', 'Negative Symptoms']
# nan
# ['Digital therapeutic', 'Whole process management', 'Lung cancer', 'Patient follow-up']
# ['Prescription digital therapeutic (PDT)', 'Software as a Medical Device (SaMD)', 'Smartphone app', 'CGRP', 'Calcitonin Gene-Related Peptide Inhibitor Therapy']
# nan
# nan
# ['PTSD']
# ['Prescription digital therapeutic (PDT)', 'Software as a Medical Device (SaMD)', 'Smartphone app']
# ['Exercise']
# ['postpartum pelvic muscle training', 'postpartum pelvic floor', 'postpartum pelvic floor physical therapy', 'postpartum urinary incontinence', 'postpartum bowel incontinence', 'postpartum pelvic floor recovery']
# ['digital', 'mobile health', 'autism', 'pediatrics']
# nan
# ['depression', 'anxiety']
# nan
# nan
# nan
# nan
# ['chronic pain', 'primary care', 'digital therapeutic', 'mobile app', 'pain function', 'pain interference', 'psychotherapy']
# ['cancer', 'digital solution', 'lifestyle change', 'prostate cancer', 'quality of life', 'digital intervention', 'side effects', 'medication adherence', 'physical activity', 'colorectal cancer', 'lung cancer']
# nan
# ['digital therapeutic']
# nan
# ['insomnia', 'CBT-I']
# ['digital therapeutic']
# nan
# nan
# ['Mental Health', 'Adolescent', 'Digital Therapeutic', 'Chatbot', 'Mental Health App']
# nan
# ['Digital therapeutic', 'Smartphone', 'Social support', 'Randomized controlled trial']
# ['Breast Cancer', 'Colon/Rectal Cancer', 'Endometrial Cancer', 'Lymphoma', 'Leukemia', 'Lung Cancer', 'Ovarian Cancer', 'Pancreatic Cancer', 'Prostate Cancer', 'Thyroid Cancer']
# nan
# ['BCBT', 'Suicide Ideation', 'Suicide Attempts', 'Depression and Anxiety']
# nan
# ['Prediabetic State', 'Digital Therapeutic', 'Mobile Health', 'Digital Health', 'Mobile Apps', 'Lifestyle Modification', 'mHealth']
# nan
# ['Depression', 'Mental Health', 'Adolescent Depression']
# nan
# ['Digital Therapeutic', 'CBT-I', 'Chronic Insomnia']
# nan
# ['Smoking Cessation', 'Smoking Cessation Program', 'Smoking Cessation Digital Therapeutic']
# nan
# ['Postpartum Depression', 'PPD', 'Postpartum Depression Treatment', 'PPD Treatment', 'Smartphone application', 'Digital therapeutic']
# ['Anxiety, worry, mindfulness, meditation']
# ['Pain', 'Emotions', 'virtual reality', 'within-subject design']
# ['Dysarthria', 'Stroke', 'digital therapeutics', 'Speech Disorders', 'Language Disorders', 'speech rehabilitation', 'application', 'Post-stroke dysarthria']
# ['Smoking', 'Cigarette Smoking', 'Tobacco Smoking', 'Nicotine', 'Drug', 'Addiction', 'Tobacco']
# nan
# ['Tobacco', 'Smoking Cessation', 'Human immunodeficiency virus (HIV)', 'Tobacco Abstinence', 'Quit Smoking']
# nan
# nan
# ['Colorectal Cancer', 'Fatigue']
# ['Depression', 'Mental Health', 'Adolescent mental health']
# nan
# nan
# nan
# nan
# ['Patient adherence', 'Mobile application', 'Mobile health', 'Digital therapeutics', 'Digital health']
# nan
# ['Overactive Bladder (OAB)']
# ['Physicians']
# ['Cognitive Behavioral Therapy for Insomnia', 'Fatigue', 'Cognitive performance']
# nan
# nan
# ['Parkinson disease', 'rhythmic auditory stimulation', 'digital therapeutics', 'behavior change', 'habits', 'physical activity']
# nan
# nan
# ['Schizophrenia', 'Digital Therapeutic', 'Schizoaffective disorder', 'Negative Symptoms']
# nan
# nan
# ['Major Depressive Disorder', 'MDD', 'depression', 'digital therapeutic']
# nan
# ['Augmented Reality', 'Smartphone application', 'Digital Therapeutic']
# nan
# ['digital therapeutic', 'behavioral', 'critical care', 'behavior modification']
# ['Mindfulness', 'Virtual Reality', 'Opioid Use Disorder']
# nan
# ['iontophoresis', 'cutaneous microcirculation', 'sildenafil', 'Healthy volunteers']
# nan
# ['Prescription digital therapeutic (PDT)', 'Software as a Medical Device (SaMD)', 'Smartphone app', 'Schizophrenia', 'Negative Symptoms']
# ['Schizophrenia', 'Digital Therapeutic', 'CBT', 'smartphone app', 'mental disorder', 'psychosis', 'acute psychotic reaction', 'chronic psychosis', 'failure to recognize what is real', 'false beliefs', 'unclear thinking,', 'confused thinking', 'auditory hallucinations', 'paranoia', 'reduced social engagement', 'reduced emotional expression']
# ['Irritable Bowel Syndrome', 'Cognitive Behavioral Therapy', 'Self Help']
# nan
# ['cancer', 'immunotherapy', 'checkpoint inhibitors', 'immune-related adverse events']
# ['Clinical Trials, Randomized', 'Prevention', 'eHealth', 'Anxiety Sensitivity']
# ['Adolescence', 'Digital Therapeutic', 'Cognitive Behavioral Therapy', 'Behavioral Activation']
# ['antithrombotic treatment', 'digital therapeutic application assistance']
# nan
# nan
# ['PTSD', 'Nightmare Disorder', 'Post-traumatic stress disorder', 'Veteran', 'Digital therapeutic', 'Digital medicine', 'Nightmares']
# ['Digital therapeutic', 'Overactive bladder', 'Urge incontinence', 'Pelvic floor disorders']
# nan
# nan
# nan
# ['Mental Health', 'Adolescence', 'Digital Therapeutic', 'Cognitive Behavioral Therapy', 'Chatbot', 'Mental Health App']
# ['Nervous System Diseases', 'Movement Disorders', 'Neurodegenerative Diseases', 'Brain Diseases', 'Central Nervous System Diseases']
# ['PTSD', 'Nightmare', 'Nightmare Disorder', 'Post-traumatic stress disorder', 'Veteran', 'Digital therapeutic', 'Digital medicine']
# ['PTSD', 'Nightmare Disorder', 'Post-traumatic stress disorder', 'Veteran', 'Digital therapeutic', 'Digital medicine', 'Nightmares']
# ['PTSD', 'Nightmare', 'Nightmare Disorder', 'Post-traumatic stress disorder', 'Veteran', 'Digital therapeutic', 'Digital medicine']
# nan
# ['Problematic Screen Use', 'Digital Therapeutics', 'Therapeutic Education Application', 'Young People', 'Mental Health', 'Physical Health']
# nan
# ['digital therapy', 'cognitive behavioral therapy', 'CBT']
# nan
# ['digital therapeutics']
# ['digital therapeutics']
# ['Cognitive Training Video Game']
# ['Schizophrenia', 'Software as a Medical Device (SaMD)', 'Smartphone app']
# ['Schizophrenia', 'Software as a Medical Device (SaMD)', 'Smartphone app']
# nan
# ['Prescription digital therapeutic (PDT)', 'Software-as-a Medical Device (SaMD)', 'Smartphone app', 'Schizophrenia']
# nan
# nan
# ['sleep', 'oxidative stress', 'aging', 'inflammation', 'sex/gender']
# nan
# ['contingency management', 'motivational incentives', 'cognitive behavioral therapy', 'CBT', 'recovery', 'recovery coach', 'recovery coaching', 'telehealth', 'digital therapeutic', 'remote monitoring', 'drug testing', 'breathalyzer', 'Medicaid', 'alcoholism', 'alcohol abuse', 'addiction']
# ['ADHD', 'AKL-T01', 'EndeavorRx', 'Akili', 'Registry']
# ['Digital health', 'User-centred design']
# ['Pre-operative Stress', 'mHealth Device', 'Virtual Reality (VR)', 'Health Recommender System', 'I-Change Behavioral Change Model', 'Artificial Intelligence (AI)', 'Software as a Medical Device (SaMD)']
# nan
# nan
# ['PostPartum depression (PPD), symptoms of PPD, Anxiety, Peri-natal depression, mild-to-moderate depression']
# ['Prescription digital therapeutic (PDT)', 'Software as a Medical Device (SaMD)', 'Smartphone app', 'Attention Biases', 'Cognition', 'Multiple Sclerosis', 'Lung Cancer', 'Breast Cancer']
# ['substance use disorders', 'mHealth', 'digital therapeutics', 'primary care', 'implementation science', 'randomized controlled trial', 'factorial trial', 'opioid use disorders']
# ['Implementation Science', 'Mobile Applications', 'Drug Use Disorders', 'Quality Improvement', 'Primary Health Care']
# ['Alcohol Use Disorder', 'Substance Use Disorder', 'AUD', 'SUD', 'AUD Treatment', 'SUD Treatment', 'Smartphone Application', 'Digital Therapeutic', 'Alcohol Use Disorder Treatment', 'Substance Use Disorder Treatment']
# ['Hyoid bone, twin block, motion,']
# nan
# nan
